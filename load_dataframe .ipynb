# %%
import pandas as pd
from sqlalchemy import create_engine

# %%
engine= create_engine("postgresql://postgres:12345@localhost:5432/ghost_job_detection")

data.to_sql(
    'job_postings',
    engine,
    if_exists='replace',
    index=False,
    
)

print(f"Data successfully loaded into table job_posting !")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 3
#       1 engine= create_engine("postgresql://postgres:12345@localhost:5432/ghost_job_detection")
# ----> 3 data.to_sql(
#       4     'job_postings',
#       5     engine,
#       6     if_exists='replace',
#       7     index=False,
#       8
#       9 )
#      11 print(f"Data successfully loaded into table job_posting !")
#
# NameError: name 'data' is not defined

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 data.head()
#
# NameError: name 'data' is not defined
