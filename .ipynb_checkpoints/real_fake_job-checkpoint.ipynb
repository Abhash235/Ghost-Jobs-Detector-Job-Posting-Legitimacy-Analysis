# %%
import numpy as np

# %%
import pandas as pd

# %%
data= pd.read_csv("fake_real_job_postings.csv") # loading data

# %% [markdown]
# ## Eplolrotary Analysis Of Data

# %%
data.head()
# Out:
#    job_id                    job_title  \
# 0       1           Software Engineer
# 1       2               Content Writer
# 2       3  Customer Support Specialist
# 3       4                 Data Analyst
# 4       5             Graphic Designer
#
#                                      job_description  \
# 0    responsibilities fast-paced fast-paced growt...
# 1    required support experience development pref...
# 2    dynamic required fast-paced responsibilities...
# 3    collaboration skills support fast-paced dyna...
# 4    team growth growth fast-paced collaboration ...
#
#                                         requirements  \
# 0    dynamic team skills fast-paced knowledge tea...
# 1    required team fast-paced responsibilities su...
# 2    preferred knowledge opportunity strategy kno...
# 3    innovation team required required developmen...
# 4    experience preferred knowledge collaboration...
#
#                                             benefits company_name  \
# ...

# %%
 data.isnull()

# %%
 data.count()

# %%
data.shape
# Out:
# (3000, 25)

# %%
data.info()

# %%
 data.describe(include='all')

# %% [markdown]
# ## Checking data quality

# %%
 data.isnull().sum() #missing values per column
# Out:
# job_id                          0
# job_title                       0
# job_description                 0
# requirements                    0
# benefits                        0
# company_name                 1472
# company_profile                 0
# industry                        0
# employment_type                 0
# location                        0
# salary_range                    0
# required_experience_years       0
# education_level                 0
# department                      0
# posting_date                    0
# application_deadline            0
# contact_email                   0
# company_website              1472
# has_logo                        0
# num_open_positions              0
# job_function                    0
# telecommuting                   0
# fraud_reason                 1528
# text_length                     0
# is_fake                         0
# dtype: int64

# %%
data.duplicated().sum() # checking duplicate rows
# Out:
# np.int64(0)

# %%
data['is_fake'].value_counts(normalize=True) * 100
# Out:
# is_fake
# 0    50.933333
# 1    49.066667
# Name: proportion, dtype: float64

# %%
data.isnull().sum() / len(data)*100  # percentage of each missing value
# Out:
# job_id                        0.000000
# job_title                     0.000000
# job_description               0.000000
# requirements                  0.000000
# benefits                      0.000000
# company_name                 49.066667
# company_profile               0.000000
# industry                      0.000000
# employment_type               0.000000
# location                      0.000000
# salary_range                  0.000000
# required_experience_years     0.000000
# education_level               0.000000
# department                    0.000000
# posting_date                  0.000000
# application_deadline          0.000000
# contact_email                 0.000000
# company_website              49.066667
# has_logo                      0.000000
# num_open_positions            0.000000
# job_function                  0.000000
# telecommuting                 0.000000
# fraud_reason                 50.933333
# text_length                   0.000000
# ...

# %%
# data pre processing 
data['Days active'] = pd.to_numeric(data['Days active'], errors='coerce').astype('Int64')

# %%
np.mean(data['Days active'])
# Out:
# np.float64(365.79037111334003)

# %%
data['company_name'].duplicated().sum() / len(data)*100
# Out:
# np.float64(70.63333333333334)

# %%
data['salary_range'].value_counts("Not Disclosed")
# Out:
# salary_range
# Not Disclosed     0.267667
# 40 000-60 000     0.261333
# 80 000-100 000    0.248333
# 60 000-80 000     0.222667
# Name: proportion, dtype: float64
